# %%
quiz_score = [80, 90, 100]

# %%
sum(quiz_score), len(quiz_score)
# Out:
# (270, 3)

# %%
quiz_average = sum(quiz_score) / len(quiz_score)

# %%
exam_scores = [70, 86, 95]

# %%
exam_average =sum(exam_scores) / len(exam_scores)
print(

# %%
def power_number(base, exponent=2):
    return base**exponent

# %%
power_number(20)
# Out:
# 400

# %%
def add_numbers(a, b):
    return a*b

# %%
x = add_numbers(2, 2)

# %%
def add_numbers_print(a, b):
    print(a+b)

# %%
y =add_numbers_print(2, 2)
# Out:
# 4

# %%
x
# Out:
# 4

# %%
def convert_to_upper(text):
    '''
    Look at this! i made a docstring!

    This function takes in some text and rerurns that text as uppercase

    '''
    return text.upper

# %%
convert_to_upper("hello")
# Out:
# <function str.upper()>

# %%
help(convert_to_upper)
# Out:
# Help on function convert_to_upper in module __main__:
#
# convert_to_upper(text)
#     Look at this! i made a docstring!
#
#     This function takes in some text and rerurns that text as uppercase

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
def create_message(name):
    message = f"Welcome, (name)"
    return message

create_message("friend")
# Out:
# 'Welcome, (name)'

# %%
scores = [88, 91, 93, 79]

type(scores)
# Out:
# list

# %%
first_score = scores[0] 

first_score
# Out:
# 88

# %%
second_score = scores[1]

second_score
# Out:
# 91

# %%
student = {
    "name": "Ava", 
    "score": 95,
    "passed": True
}

# %%
student["name"]
# Out:
# 'Ava'

# %%
# import pandas, with the alias
import pandas as pd

# %%
df =pd.dataframe(boring_dict)

print(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df =pd.dataframe(boring_dict)
#       3 print(df)
#
# AttributeError: module 'pandas' has no attribute 'dataframe'
