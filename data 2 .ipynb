# %%
j = 14

# %%
x = 7

# %%
j + x
# Out:
# 21

# %% [markdown]
# ## MarkDown Cell
# This Code adds J which is 14 to X which is a value of 7 to get us the sum of 21.

# %%
Gas = 4

# %%
4 >= 3.80
# Out:
# True

# %%
if Gas >= 4:
    print('Next station!')
else:
    print('Get Gas HERE!')
# Out:
# Next station!

# %% [markdown]
# ## MarkDown Cell
#
# Made an if/else statement for Gas. If Gas is over or equal to 4 dollars go somewhere else, but if its less than 3 dollars get gas there.

# %%
Name = 'Johnny'

# %%
for n in 'Johnny':
    print(n)
# Out:
# J
# o
# h
# n
# n
# y

# %%
for n in 'name':
    print(n)
# Out:
# n
# a
# m
# e

# %% [markdown]
# ## MarkDown Cell
# I chose the name Johnny As loop and n to get overwritten each pass of the loop. I then changed the variable to name just to see what would happen.
